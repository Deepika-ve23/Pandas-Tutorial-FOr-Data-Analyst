# %%
# Install Pandas

# %%
# !pip install pandas
# Out:
# ...
# [notice] A new release of pip is available: 25.3 -> 26.0.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %% [markdown]
# # import pandas

# %%
import pandas as pd

# %%
pd.__version__
# Out:
# '3.0.1'

# %% [markdown]
# # 1. Dataframe

# %%
df = pd.DataFrame([11,22,33],columns=['Col_Name'])
print(df)
# Out:
#    Col_Name
# 0        11
# 1        22
# 2        33

# %%
print(type(df))
# Out:
# <class 'pandas.DataFrame'>

# %%
data = {
    'Name' : ['Deepika' ,'Ekta' , 'Amit' , 'Kishor'],
    'Age'  : [16 ,17,18,19 ],
    'Salery' :  [90000 , 70000 , 50000, 30000],
}

# %%
df = pd.DataFrame(data)
print(df)
# Out:
#       Name  Age  Salery
# 0  Deepika   16   90000
# 1     Ekta   17   70000
# 2     Amit   18   50000
# 3   Kishor   19   30000

# %%
print(type(df))
# Out:
# <class 'pandas.DataFrame'>

# %%
df.head(2)
# Out:
#       Name  Age  Salery
# 0  Deepika   16   90000
# 1     Ekta   17   70000

# %%
df.tail(2)
# Out:
#      Name  Age  Salery
# 2    Amit   18   50000
# 3  Kishor   19   30000

# %%
df.shape
# Out:
# (4, 3)

# %%
df.rename(columns = {'Salery': 'Monthly_Salery'},inplace =True)

# %%
df
# Out:
#       Name  Age  Monthly_Salery
# 0  Deepika   16           90000
# 1     Ekta   17           70000
# 2     Amit   18           50000
# 3   Kishor   19           30000

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 4 entries, 0 to 3
# Data columns (total 3 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Name            4 non-null      str
#  1   Age             4 non-null      int64
#  2   Monthly_Salery  4 non-null      int64
# dtypes: int64(2), str(1)
# memory usage: 228.0 bytes

# %%
df.describe()
# Out:
#              Age  Monthly_Salery
# count   4.000000        4.000000
# mean   17.500000    60000.000000
# std     1.290994    25819.888975
# min    16.000000    30000.000000
# 25%    16.750000    45000.000000
# 50%    17.500000    60000.000000
# 75%    18.250000    75000.000000
# max    19.000000    90000.000000

# %%
df.to_csv('Test_data.csv' , index = False) # Export Data Frame

# %%
load_df = pd.read_csv('Test_data.csv')  # import Data Frame
print(load_df)
# Out:
#       Name  Age  Monthly_Salery
# 0  Deepika   16           90000
# 1     Ekta   17           70000
# 2     Amit   18           50000
# 3   Kishor   19           30000

# %% [markdown]
# # Select Cloumns

# %%
df[['Name' , 'Monthly_Salery']]
# Out:
#       Name  Monthly_Salery
# 0  Deepika           90000
# 1     Ekta           70000
# 2     Amit           50000
# 3   Kishor           30000

# %% [markdown]
# ## Select Rows

# %%
df.loc[df.Name=='Deepika']
# Out:
#       Name  Age  Monthly_Salery
# 0  Deepika   16           90000

# %%
df.iloc[(df.Name == 'Deepika') & (df.Monthly_Salery >= 50000)]
# Out:
#       Name  Age  Monthly_Salery
# 0  Deepika   16           90000

# %% [markdown]
# # iloc  - index-value based

# %%
df.iloc[0] # index based value
# Out:
# Name              Deepika
# Age                    16
# Monthly_Salery      90000
# Name: 0, dtype: object

# %%
df.iloc[0:2]  # (start:stop:step: )
# Out:
#       Name  Age  Monthly_Salery
# 0  Deepika   16           90000
# 1     Ekta   17           70000

# %%
df.loc[0:2]
# Out:
#       Name  Age  Monthly_Salery
# 0  Deepika   16           90000
# 1     Ekta   17           70000
# 2     Amit   18           50000

# %% [markdown]
# # Filter Dataframe

# %%
df
# Out:
#       Name  Age  Monthly_Salery
# 0  Deepika   16           90000
# 1     Ekta   17           70000
# 2     Amit   18           50000
# 3   Kishor   19           30000

# %%
df['Age'] >18
# Out:
# 0    False
# 1    False
# 2    False
# 3     True
# Name: Age, dtype: bool

# %%
df[df['Age'] >=18]
# Out:
#      Name  Age  Monthly_Salery
# 2    Amit   18           50000
# 3  Kishor   19           30000

# %%
df_age_filter
# Out:
#      Name  Age  Monthly_Salery
# 2    Amit   18           50000
# 3  Kishor   19           30000

# %%
df[(df['Age'] >=18) & (df['Monthly_Salery'] >= 50000)]
# Out:
#    Name  Age  Monthly_Salery
# 2  Amit   18           50000

# %%
df.where(df['Age'] >=18)
# Out:
#      Name   Age  Monthly_Salery
# 0     NaN   NaN             NaN
# 1     NaN   NaN             NaN
# 2    Amit  18.0         50000.0
# 3  Kishor  19.0         30000.0

# %%
df.where(df['Age'] >=18 ,other = 'Not elegible')
# Out:
#            Name           Age Monthly_Salery
# 0  Not elegible  Not elegible   Not elegible
# 1  Not elegible  Not elegible   Not elegible
# 2          Amit            18          50000
# 3        Kishor            19          30000
